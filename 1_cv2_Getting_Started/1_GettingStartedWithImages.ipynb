# %% [markdown]
# Goals
#
# Here, you will learn how to read an image, how to display it and how to save it back
# You will learn these functions : cv2.imread(), cv2.imshow() , cv2.imwrite()
# Optionally, you will learn how to display images with Matplotlib

# %%
import numpy as np
import cv2

# Load an color image in grayscale
img = cv2.imread('bukovel.jpg',0)

# %%
cv2.imshow('image',img)
k = cv2.waitKey(0) & 0xFF
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('bukovelGray.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# Displaying the image in BGR

# %%
from matplotlib import pyplot as plt

plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# Display the images in BGR and RGB

# %%
# Load an color image in grayscale
img = cv2.imread('bukovel.jpg',1)
# b,g,r = cv2.split(img)
img2 = img[..., ::-1]
plt.subplot(131);plt.imshow(img) # expects distorted color
cv2.imwrite('bukovelBGR.png',img2)
plt.subplot(132);plt.imshow(img2) # expect true color
plt.show()

# %% [markdown]
# Convert the image from BGR to RGB using cv2.COLOR_BGR2RGB

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Conver the image from BGR to RGB using splitting into chanels

# %%
b,g,r = cv2.split(img)
img2 = cv2.merge([r,g,b])
plt.imshow(img2)
plt.show()

# %%
image = cv2.imread('bukovel.jpg')

import sys
import os
import numpy as np
import cv2

rgbImages = []

def main():
#     exts = ['.bmp', '.pbm', '.pgm', '.ppm', '.sr', '.ras', '.jpeg', '.jpg', 
#     '.jpe', '.jp2', '.tiff', '.tif', '.png']
    filenames = ['bukovel.jpg']
    for filename in filenames:
        img = cv2.imread(filename)
        blue, green, red = cv2.split(img)

        for values, color, channel in zip((red, green, blue),('red', 'green', 'blue'), (2,1,0)):
            img = np.zeros((values.shape[0], values.shape[1], 3), dtype = values.dtype) 
            img[:,:,channel] = values
            cv2.imwrite('bukovel'+color+'.png', img)
            rgbImages.append(img)

if __name__ == "__main__":
    main()

images_size = len(rgbImages);

for index, img in zip(range(images_size), rgbImages):
    cartezian_place = 100 + images_size * 10 + index + 1
    plt.subplot(cartezian_place)
    plt.imshow(img)
plt.show()

# %%
img = image[:, :, 0]
cv2.imwrite('bukovelBlueGray.png',img)
img = image[:, :, 1]
cv2.imwrite('bukovelGreenGray.png',img)
img = image[:, :, 2]
cv2.imwrite('bukovelRedGray.png',img)
# Out:
# True
