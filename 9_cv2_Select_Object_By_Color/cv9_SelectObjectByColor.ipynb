# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
cap = cv2.VideoCapture(0)

while(1):
    _, frame = cap.read()
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # define range of blue color in HSV
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([130,255,255])
    
    # define range of green color in HSV
    lower_green = np.array([50, 50, 50])
    upper_green = np.array([70, 255, 255])
    
    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    
    mask = cv2.bitwise_or(mask_blue, mask_green)
    
    res = cv2.bitwise_and(frame, frame, mask = mask)
    
    cv2.imshow('frame', frame)
    cv2.imshow('mask', mask)
    cv2.imshow('res', res)
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
        
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
green = np.uint8([[[0,255,0 ]]])
hsv_green = cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
print(hsv_green)
# Out:
# [[[ 60 255 255]]]

# %%
red = np.uint8([[[0,0,255]]])
hsv_red = cv2.cvtColor(red,cv2.COLOR_BGR2HSV)
print(hsv_red)
# Out:
# [[[  0 255 255]]]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def display_blue_red(file_name):
    img = cv2.imread(file_name)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    # define range of blue color in HSV
    lower_blue = np.array([100,50,50]) #it's not taken from 0 as an experiment
    upper_blue = np.array([140,255,255])

    # define range of green color in HSV
    lower_red = np.array([0, 0, 0])
    upper_red = np.array([20, 255, 255])

    # define range of green color in HSV
    lower_red2 = np.array([140, 25, 25])
    upper_red2 = np.array([180, 255, 255])

    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_red = cv2.inRange(hsv, lower_red, upper_red)
    mask_red2 = cv2.inRange(hsv, lower_red2, upper_red2)

    mask = cv2.bitwise_or(mask_blue, mask_red)
    mask = cv2.bitwise_or(mask, mask_red2)

    res = cv2.bitwise_and(img, img, mask = mask)
    
    return img, mask, res

# %%
img, mask, result = display_blue_red('TSKh8.png')

plt.imshow(img[..., ::-1])

# %%
plt.imshow(mask)

# %%
plt.imshow(result[..., ::-1])

# %%
img, mask, result = display_blue_red('pencils.jpeg')

plt.imshow(img[..., ::-1])

# %%
plt.imshow(mask)

# %%
plt.imshow(result[..., ::-1])
