# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('jupiter.jpg')
hist = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
def histEqulColor(img):
    ycrcb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    channels=cv2.split(ycrcb)
    print(len(channels))
    cv2.equalizeHist(channels[0],channels[0])
    cv2.merge(channels,ycrcb)
    cv2.cvtColor(ycrcb,cv2.COLOR_RGB2BGR,img)
    return img

def plotHistogram(img):
    colors = ['b', 'g', 'r']
    for i, col in enumerate(colors):
        hist = cv2.calcHist([img],[i],None,[256],[0,256])
        plt.plot(hist, color = col)
        plt.xlim([0, 255])
    plt.show()

# %%
img2 = histEqulColor(img)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
# Out:
# 3

# %%
plotHistogram(img2)

# %%
img = cv2.imread('statue.jpg', 0)
img2 = cv2.equalizeHist(img)
plt.figure(figsize=(12, 10))
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
# you can notice that image is too white and details of statues are lost

# %%
colors = ['b', 'g', 'r']
plotHistogram(img2)

# %%
img = cv2.imread('statue.jpg',0)

# create a CLAHE object (Arguments are optional).
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

cv2.imwrite('clahe_2.jpg',cl1)
# Out:
# True

# %%
plt.figure(figsize=(12, 10))
plt.imshow(cl1, cmap='gray', vmin=0, vmax=255)
